# %% [markdown]
# ## Iteration Changelog
# - Added baseline and alternate model training/evaluation for bluff prediction.
# - Added win probability and money regression model pipelines with artifact persistence.
# - Open issues: finalize leakage-safe temporal splits by tournament/session boundaries.
